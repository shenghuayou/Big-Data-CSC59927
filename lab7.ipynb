# %%
SAT_FN = 'SAT_Results.csv'
HSD_FN = 'DOE_High_School_Directory_2014-2015.csv'

# %%
import csv
with open(HSD_FN, 'rb') as fi:
    reader = csv.reader(fi)
    print reader.next()
    print reader.next()
#     print fi.next()
#     print fi.next()
#     print fi.next()
#     print fi.next()
# Out:
# ['dbn', 'school_name', 'boro', 'building_code', 'phone_number', 'fax_number', 'grade_span_min', 'grade_span_max', 'expgrade_span_min', 'expgrade_span_max', 'bus', 'subway', 'primary_address_line_1', 'city', 'state_code', 'zip', 'website', 'total_students', 'campus_name', 'school_type', 'overview_paragraph', 'program_highlights', 'language_classes', 'advancedplacement_courses', 'online_ap_courses', 'online_language_courses', 'extracurricular_activities', 'psal_sports_boys', 'psal_sports_girls', 'psal_sports_coed', 'school_sports', 'partner_cbo', 'partner_hospital', 'partner_highered', 'partner_cultural', 'partner_nonprofit', 'partner_corporate', 'partner_financial', 'partner_other', 'addtl_info1', 'addtl_info2', 'start_time', 'end_time', 'se_services', 'ell_programs', 'school_accessibility_description', 'number_programs', 'priority01', 'priority02', 'priority03', 'priority04', 'priority05', 'priority06', 'priority07', 'priority08', 'priority09', 'priority10', 'Location 1']
# ['01M292', 'Henry Street School for International Studies', 'Manhattan', 'M056', '212-406-9411', '212-406-9417', '6', '12', '', '', 'B39, M14A, M14D, M15, M15-SBS, M21, M22, M9', 'B, D to Grand St ; F to East Broadway ; J, M, Z to Delancey St-Essex St', '220 Henry Street', 'New York', 'NY', '10002', 'http://schools.nyc.gov/schoolportals/01/M292', '323', 'N/A', '', 'Henry Street School for International Studies is a unique small school founded by the Asia Society. While in pursuit of knowledge about other world regions, including their histories, economies and world languages, students acquire the knowledge and skills needed to prepare for college and/or careers. Teachers and other adults who make up the learning community forge supportive relationships with students and parents while providing challenging and engaging learning experiences. Our school partners with various community, arts and business organizations to help students achieve success. Our theme of international studies extends beyond the classroom, where students participate in ongoing \xe2\x80\x98Advisory Day Out\xe2\x80\x99 excursions where the multiculturalism of NYC becomes the classroom.', 'Global/International Studies in core subjects, Literacy block schedule, Personalized instruction in small classes, Student Advisories, International travel opportunities, After-school program focused on youth leadership', 'Chinese (Mandarin), Spanish', 'Psychology', 'Chinese Language and Culture, Spanish Literature and Culture', 'Chinese (Mandarin), Spanish', 'Math through Card Play; Art, Poetry/Spoken Word, Drama, Book, STEP, Big Brothers/Big Sisters, Student Government/Leadership, Future Project', 'Basketball', 'Softball', 'Soccer', 'Boxing, Track, CHAMPS, Tennis, Flag Football, Softball', 'The Henry Street Settlement; Asia Society; America Reads; Future Project; 21st Century Grant', 'Gouverneur Hospital (Turning Points)', 'New York University', 'Asia Society', 'Heart of America Foundation', '', '', 'United Nations', '', '', '8:30 AM', '3:30 PM', 'This school will provide students with disabilities the supports and services indicated on their IEPs.', 'ESL', 'Functionally Accessible', '1', 'Priority to continuing 8th graders', 'Then to Manhattan students or residents who attend an information session', 'Then to New York City residents who attend an information session', 'Then to Manhattan students or residents', 'Then to New York City residents', '', '', '', '', '', '220 Henry Street\nNew York, NY 10002\n(40.71376394700047, -73.98526003999967)']

# %%
df = spark.read \
        .format('com.databricks.spark.csv') \
        .option('header','true') \
        .option('inferSchema','true') \
        .option('parserLib','UNIVOCITY') \
        .load(HSD_FN)

# %%
sat = sc.textFile(SAT_FN,use_unicode=False).cache()

# %%
list(enumerate(sat.first().split(',')))
# Out:
# [(0, 'DBN'),
#  (1, 'SCHOOL NAME'),
#  (2, 'Num of SAT Test Takers'),
#  (3, 'SAT Critical Reading Avg. Score'),
#  (4, 'SAT Math Avg. Score'),
#  (5, 'SAT Writing Avg. Score')]

# %%
noHeaderSat = sat.filter(lambda x: not x.startswith('DBN,'))
noHeaderSat.first()
# Out:
# '02M047,47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL,16,395,400,387'

# %%
def extractScores(partitionId,partition):
    if partitionId==0:
        partition.next()
    import csv
    reader = csv.reader(partition)
    for row in reader:
        if row[2] !='s':
            (dbn,takers,score) = (row[0], int(row[2]), int(row[4]))
            yield (dbn, (score*takers, takers))

satScores = sat.mapPartitionsWithIndex(extractScores)
satScores.take(5)
# Out:
# [('02M047', (6400, 16)),
#  ('21K410', (207575, 475)),
#  ('30Q301', (43120, 98)),
#  ('17K382', (22066, 59)),
#  ('18K637', (13335, 35))]

# %%
sat.getNumPartitions()
# Out:
# 2

# %%
schools = sc.textFile(HSD_FN,use_unicode=False).cache()
list(enumerate(schools.first().split(',')))
# Out:
# [(0, 'dbn'),
#  (1, 'school_name'),
#  (2, 'boro'),
#  (3, 'building_code'),
#  (4, 'phone_number'),
#  (5, 'fax_number'),
#  (6, 'grade_span_min'),
#  (7, 'grade_span_max'),
#  (8, 'expgrade_span_min'),
#  (9, 'expgrade_span_max'),
#  (10, 'bus'),
#  (11, 'subway'),
#  (12, 'primary_address_line_1'),
#  (13, 'city'),
#  (14, 'state_code'),
#  (15, 'zip'),
#  (16, 'website'),
#  (17, 'total_students'),
#  (18, 'campus_name'),
#  (19, 'school_type'),
#  (20, 'overview_paragraph'),
#  (21, 'program_highlights'),
#  (22, 'language_classes'),
#  (23, 'advancedplacement_courses'),
#  (24, 'online_ap_courses'),
#  (25, 'online_language_courses'),
#  (26, 'extracurricular_activities'),
#  (27, 'psal_sports_boys'),
#  (28, 'psal_sports_girls'),
#  (29, 'psal_sports_coed'),
#  (30, 'school_sports'),
#  (31, 'partner_cbo'),
#  (32, 'partner_hospital'),
#  (33, 'partner_highered'),
#  (34, 'partner_cultural'),
#  (35, 'partner_nonprofit'),
#  (36, 'partner_corporate'),
#  (37, 'partner_financial'),
#  (38, 'partner_other'),
#  (39, 'addtl_info1'),
#  (40, 'addtl_info2'),
#  (41, 'start_time'),
#  (42, 'end_time'),
#  (43, 'se_services'),
#  (44, 'ell_programs'),
#  (45, 'school_accessibility_description'),
#  (46, 'number_programs'),
#  (47, 'priority01'),
#  (48, 'priority02'),
#  (49, 'priority03'),
#  (50, 'priority04'),
#  (51, 'priority05'),
#  (52, 'priority06'),
#  (53, 'priority07'),
#  (54, 'priority08'),
#  (55, 'priority09'),
#  (56, 'priority10'),
#  (57, 'Location 1')]

# %%
def extractSchools(partitionId, partition):
    if partitionId==0:
        partition.next()
    import csv
    reader = csv.reader(partition)
    for row in reader:
        if len(row)==58 and row[17].isdigit():
            (dbn,boro,total_students) = (row[0],row[2], int(row[17]))
            if total_students>500:
                yield (dbn,boro)
    
largeSchools = schools.mapPartitionsWithIndex(extractSchools)
largeSchools.take(5)
# Out:
# [('01M450', 'Manhattan'),
#  ('01M539', 'Manhattan'),
#  ('01M696', 'Manhattan'),
#  ('02M374', 'Manhattan'),
#  ('02M400', 'Manhattan')]

# %%
largeSchools.join(satScores).values().take(5)
# Out:
# [('Bronx', (23069, 59)),
#  ('Staten Island', (52216, 107)),
#  ('Bronx', (16317, 49)),
#  ('Brooklyn', (33235, 85)),
#  ('Bronx', (24570, 65))]

# %%
largeSchools.join(satScores).values() \
    .reduceByKey(lambda x,y: (x[0]+y[0],x[1]+y[1])) \
    .mapValues(lambda x: x[0]/x[1]) \
    .take(5)
# Out:
# [('Bronx', 470),
#  ('Manhattan', 514),
#  ('Brooklyn', 487),
#  ('Staten Island', 477),
#  ('Queens', 474)]

# %%
bus = sc.textFile(HSD_FN,use_unicode=False).cache()

# %%
def extractBus(partitionId, partition):
    if partitionId==0:
        partition.next()
    import csv
    reader = csv.reader(partition)
    for row in reader:
        if len(row)==58 and row[17].isdigit():
            (dbn ,bus) = (row[0],row[10])
            for busLines in bus.split(', '):
                yield (dbn, busLines)
    
bus_data = schools.mapPartitionsWithIndex(extractBus)

def extractSubway(partitionId, partition):
    if partitionId==0:
        partition.next()
    import csv
    reader = csv.reader(partition)
    for row in reader:
        if len(row)==58 and row[17].isdigit():
            (dbn, subway) = (row[0],row[11])
            for subwayLines in subway.split(', '):
                yield (dbn, subwayLines)
    
subway_data = schools.mapPartitionsWithIndex(extractSubway)
#bus_data.take(5)

# %%
a = bus_data.join(satScores).values() \
            .reduceByKey(lambda x,y: (x[0]+y[0],x[1]+y[1])) \
            .mapValues(lambda x: x[0]/x[1])
b = subway_data.join(satScores).values() \
                .reduceByKey(lambda x,y: (x[0]+y[0],x[1]+y[1])) \
                .mapValues(lambda x: x[0]/x[1])

# %%
final = a.collect() + b.collect()
sorted(final)
# Out:
# [('1', 532),
#  ('1 to 137th St - City College ; 2', 399),
#  ('1 to 137th St - City College ; A', 516),
#  ('1 to 157th St ; B', 376),
#  ('1 to 18th St ; 2', 498),
#  ('1 to 191st St ; A to 190th St', 384),
#  ('1 to 231st St', 393),
#  ('1 to 66th St - Lincoln Center ; 2', 514),
#  ('1 to 66th St - Lincoln Center ; A', 575),
#  ('1 to Chambers St ; 2', 440),
#  ('1 to Dyckman St ; A to 190th St', 446),
#  ('1 to Marble Hill - 225th St', 406),
#  ('1 to Rector St ; 2', 489),
#  ('2', 494),
#  ('2 to 149th St-Grand Concourse ; 3 to 145th St ; 4', 365),
#  ('2 to 149th St-Grand Concourse ; 4', 381),
#  ('3', 547),
#  ('3 to 34th St - Penn Station ; A', 423),
#  ('3 to 72nd St ; A', 514),
#  ('3 to Central Park North-110th St ; 6 to 103rd St', 446),
#  ('3 to Central Park North-110th St ; 6 to 103rd St ; 6 to 110th St', 421),
#  ('3 to Eastern Parkway-Brooklyn Museum ; C to Franklin Ave ; F', 364),
#  ('3 to Harlem - 148 St ; A', 474),
#  ('3 to Hoyt St ; A', 402),
#  ('3 to Pennsylvania Ave ; C to Van Siclen Ave ; L to Livonia Ave', 364),
#  ('3 to Rockaway Ave', 396),
#  ('3 to Van Siclen Ave', 432),
#  ('3 to Wall St ; 4', 471),
#  ('4', 492),
#  ('4 to 176th St ; B', 339),
#  ('4 to 183rd St ; B', 391),
#  ('4 to Bedford Park Blvd - Lehman College ; B', 683),
#  ('4 to Mosholu Parkway ; B', 426),
#  ('5', 428),
#  ('5 to 138th St - Grand Concourse ; 6 to 138th St-3rd Ave', 369),
#  ('5 to 149th St-3rd Ave ; 4 to 138th St - Grand Concourse ; 6 to 138th St-3rd Ave',
#   378),
#  ('5 to 149th St-3rd Ave ; 4 to 149th St-Grand Concourse', 400),
#  ('5 to 149th St-3rd Ave ; 6 to Brook Ave', 324),
#  ('5 to 149th St-Grand Concourse ; B', 384),
#  ('5 to 174th St', 379),
#  ('5 to 225th St', 382),
#  ('5 to Baychester Ave', 392),
#  ('5 to Borough Hall ; A', 393),
#  ('5 to Bowling Green', 423),
#  ('5 to Bowling Green ; A', 471),
#  ('5 to Bronx Park East', 433),
#  ('5 to Brooklyn College - Flatbush Ave', 519),
#  ('5 to East 180th St', 374),
#  ('5 to Freeman St ; 6 to Whitlock Ave', 346),
#  ('5 to Gun Hill Rd', 377),
#  ('5 to Intervale Av ; 2', 432),
#  ('5 to Intervale Ave', 360),
#  ('5 to Jackson Ave', 385),
#  ("5 to Jackson Ave ; 6 to East 143rd St-St Mary's St", 396),
#  ("5 to Jackson Ave ; 6 to East 149th St - St Mary's St", 426),
#  ('5 to Nevins St ; A to Hoyt & Schermerhorn ; B', 659),
#  ('5 to Pelham Parkway', 439),
#  ('5 to President St ; 3 to Nostrand Ave ; 4', 481),
#  ('5 to Prospect Ave ; 6 to Longwood Ave', 376),
#  ('5 to Simpson St', 380),
#  ('5 to Wall St ; 6 to Brooklyn Bridge - City Hall ; E to World Trade Center ; J',
#   467),
#  ('5 to Winthrop St', 417),
#  ('6', 445),
#  ('6 to 103rd St', 368),
#  ('6 to 125th St ; 6 to 116th St', 357),
#  ('6 to 77th St', 594),
#  ('6 to 96th St', 424),
#  ('6 to Astor Place ; L to 1st Ave', 402),
#  ('6 to Elder Ave', 343),
#  ('6 to Grand Central - 42nd St ; 7', 404),
#  ('6 to Grand Central - 42nd St ; 7 to 42nd St-Bryant Park ; A', 425),
#  ('6 to Westchester Sq - East Tremont Ave', 430),
#  ('6 to Whitlock Ave', 370),
#  ('7', 476),
#  ('7 to 45 Rd-Court House Sq ; E', 434),
#  ('7 to Flushing - Main St', 438),
#  ('7 to Junction Blvd', 381),
#  ('7 to Lowery St-40th St', 447),
#  ('7 to Rawson St-33rd St', 496),
#  ('7 to Rawson St-33rd St ; E', 472),
#  ('7 to Vernon Blvd-Jackson Ave ; G to 21st St', 440),
#  ('A', 534),
#  ('A to 104th St-Oxford Ave', 409),
#  ('A to 181st St', 395),
#  ('A to Beach 25th St-Wavecrest', 387),
#  ('A to Broadway Junction ; C to Rockaway Ave', 409),
#  ('A to Nostrand Ave ; C', 443),
#  ('A to Utica Ave ; C to Ralph Ave ; J to Halsey St', 372),
#  ('B', 454),
#  ('B to Brighton Beach ; F to Neptune Av-Van Siclen ; Q to Ocean Parkway',
#   437),
#  ('B1', 461),
#  ('B100', 475),
#  ('B103', 531),
#  ('B11', 503),
#  ('B12', 390),
#  ('B13', 397),
#  ('B14', 390),
#  ('B15', 382),
#  ('B16', 448),
#  ('B17', 385),
#  ('B2', 475),
#  ('B20', 372),
#  ('B24', 432),
#  ('B25', 541),
#  ('B26', 389),
#  ('B3', 382),
#  ('B31', 475),
#  ('B32', 409),
#  ('B35', 390),
#  ('B36', 432),
#  ('B38', 520),
#  ('B39', 438),
#  ('B4', 466),
#  ('B41', 520),
#  ('B42', 384),
#  ('B43', 411),
#  ('B44', 465),
#  ('B44-SBS', 465),
#  ('B45', 534),
#  ('B46', 390),
#  ('B47', 374),
#  ('B48', 412),
#  ('B49', 471),
#  ('B52', 560),
#  ('B54', 543),
#  ('B57', 405),
#  ('B6', 467),
#  ('B60', 398),
#  ('B61', 400),
#  ('B62', 513),
#  ('B63', 557),
#  ('B64', 454),
#  ('B65', 538),
#  ('B67', 420),
#  ('B68', 465),
#  ('B69', 548),
#  ('B7', 378),
#  ('B70', 476),
#  ('B8', 485),
#  ('B82', 440),
#  ('B83', 376),
#  ('B84', 432),
#  ('B9', 489),
#  ('Bx1', 464),
#  ('Bx10', 534),
#  ('Bx11', 389),
#  ('Bx12', 405),
#  ('Bx12-SBS', 405),
#  ('Bx13', 398),
#  ('Bx15', 393),
#  ('Bx17', 389),
#  ('Bx18', 382),
#  ('Bx19', 413),
#  ('Bx2', 470),
#  ('Bx20', 455),
#  ('Bx21', 398),
#  ('Bx22', 525),
#  ('Bx23', 392),
#  ('Bx24', 430),
#  ('Bx26', 533),
#  ('Bx27', 371),
#  ('Bx28', 489),
#  ('Bx29', 392),
#  ('Bx3', 571),
#  ('Bx30', 401),
#  ('Bx31', 417),
#  ('Bx32', 397),
#  ('Bx33', 426),
#  ('Bx34', 416),
#  ('Bx35', 389),
#  ('Bx36', 372),
#  ('Bx38', 378),
#  ('Bx39', 395),
#  ('Bx4', 391),
#  ('Bx40', 400),
#  ('Bx41', 388),
#  ('Bx41-SBS', 389),
#  ('Bx42', 400),
#  ('Bx46', 376),
#  ('Bx4A', 391),
#  ('Bx5', 382),
#  ('Bx6', 396),
#  ('Bx7', 402),
#  ('Bx8', 409),
#  ('Bx9', 389),
#  ('C', 527),
#  ('C to 116th St', 374),
#  ('C to 135th St', 516),
#  ('C to 135th St ; A', 400),
#  ('C to 168th St - Washington Hts', 349),
#  ('C to Euclid Ave', 400),
#  ('C to Euclid Ave ; J', 418),
#  ('C to Fulton St-Broadway-Nassau ; 4', 453),
#  ('C to Fulton St-Broadway-Nassau ; E to World Trade Center ; J', 471),
#  ('C to High St ; B', 384),
#  ('C to Hoyt & Schermerhorn ; F', 396),
#  ('C to Liberty Ave ; J to Alabama Ave ; L to Atlantic Ave ; Z to Van Siclen Ave',
#   369),
#  ('C to Utica Ave', 370),
#  ('D', 422),
#  ('D to 125th St', 382),
#  ('D to 125th St ; B', 456),
#  ('D to 145th St', 474),
#  ('D to 145th St ; B', 654),
#  ('D to 155th St ; C to 163rd St - Amsterdam Ave', 376),
#  ('D to 161st St-Yankee Stadium', 396),
#  ('D to 170th St', 387),
#  ('D to 174th-175th Sts', 376),
#  ('D to 182nd-183rd Sts', 391),
#  ('D to 20th Ave', 449),
#  ('D to 25th Ave ; N to Ave U ; N to Gravesend - 86th St', 382),
#  ('D to 34th St-Herald Square', 520),
#  ('D to 59th St-Columbus Circle', 528),
#  ('D to 59th St-Columbus Circle ; E to 50th St ; N', 493),
#  ('D to 79th St', 471),
#  ('D to 7th Ave ; F', 490),
#  ('D to Bay 50th St ; F to Ave X ; N to Gravesend - 86th St', 468),
#  ('D to Bedford Park Blvd', 593),
#  ('D to Fordham Rd', 385),
#  ('D to Grand St ; F', 439),
#  ('D to Grand St ; F to East Broadway ; J', 429),
#  ('D to Kingsbridge Rd', 372),
#  ('E', 458),
#  ('E to 42nd St-Port Authority Bus Terminal', 404),
#  ('E to 42nd St-Port Authority Bus Terminal ; B', 425),
#  ('E to 50th St', 386),
#  ('E to 50th St ; 2', 490),
#  ('E to Chambers St ; R to City Hall', 735),
#  ('E to Spring St ; N', 452),
#  ('F', 451),
#  ('F to 169th St', 472),
#  ('F to Bay Parkway-22nd Av ; N to 20th Ave', 486),
#  ('F to East Broadway ; J', 423),
#  ('F to Jay St-MetroTech ; B', 417),
#  ('F to Neptune Ave-Van Siclen ; Q to Ocean Parkway ; Q to West 8th St - NY Aquarium',
#   427),
#  ('G', 435),
#  ('G to 7th Ave', 406),
#  ('G to Bergen St', 396),
#  ('G to Broadway ; J', 355),
#  ('G to Carroll St', 399),
#  ('G to Classon Ave', 355),
#  ('G to Fort Hamilton Parkway', 456),
#  ('G to Metropolitan Ave-Lorimer St ; J', 429),
#  ('G to Nassau Ave ; L to Bedford Ave', 375),
#  ('J', 455),
#  ('J to 111th St ; Z to 121st St', 404),
#  ('J to Kosciusko St ; M', 355),
#  ('J to Kosciusko St ; M to Central Ave ; Z to Gates Ave', 358),
#  ('J to Kosciusko St ; M to Central Ave ; Z to Myrtle Ave', 409),
#  ('L', 443),
#  ('L to 14th St - 6th Ave ; 4', 473),
#  ('L to 14th St-8th Ave', 498),
#  ('L to 14th St-8th Ave ; B', 423),
#  ('L to Canarsie - Rockaway Pkwy', 384),
#  ('L to Grand St', 398),
#  ('M', 471),
#  ('M to 14th St - 6th Ave ; 4', 391),
#  ('M to 14th St ; A', 498),
#  ('M to 23rd St ; 2', 423),
#  ('M to 42nd St-Bryant Park ; A', 404),
#  ('M to 47-50th Sts Rockefeller Center ; N', 452),
#  ('M to Broadway-Lafayette St ; C', 452),
#  ('M to Ely Ave-23rd St ; F to 21st St - Queensbridge ; N', 434),
#  ('M to Hewes St ; Z to Marcy Ave', 355),
#  ('M to Lexington Ave-53 St ; F to Lexington Ave-63 St', 441),
#  ('M to Lorimer St ; L to Grand St', 483),
#  ('M to Myrtle Ave-Wyckoff Ave', 377),
#  ('M1', 413),
#  ('M10', 495),
#  ('M100', 427),
#  ('M101', 453),
#  ('M102', 455),
#  ('M103', 441),
#  ('M104', 477),
#  ('M106', 470),
#  ('M11', 477),
#  ('M116', 467),
#  ('M14A', 475),
#  ('M14D', 468),
#  ('M15', 459),
#  ('M15-SBS', 452),
#  ('M2', 449),
#  ('M20', 540),
#  ('M21', 485),
#  ('M22', 574),
#  ('M23', 462),
#  ('M3', 432),
#  ('M31', 490),
#  ('M34-SBS', 417),
#  ('M34A-SBS', 437),
#  ('M35', 496),
#  ('M4', 442),
#  ('M42', 410),
#  ('M5', 520),
#  ('M50', 438),
#  ('M57', 485),
#  ('M60', 357),
#  ('M66', 518),
#  ('M7', 483),
#  ('M72', 523),
#  ('M79', 594),
#  ('M8', 467),
#  ('M86', 538),
#  ('M9', 539),
#  ('M96', 401),
#  ('M98', 409),
#  ('N', 450),
#  ('N to 59th St ; R to Bay Ridge Ave', 474),
#  ('N to Atlantic Ave - Barclays Center ; G to Fulton St', 659),
#  ('N/A', 423),
#  ('N/A', 476),
#  ('Q', 531),
#  ('Q to 14th St-Union Square ; 6', 538),
#  ('Q to 14th St-Union Square ; A to 14th St-8th Ave ; B', 473),
#  ('Q to 34th St-Herald Square ; N', 423),
#  ('Q to 36 Ave-Washington Ave', 514),
#  ('Q to Ave M', 496),
#  ('Q to Brighton Beach', 414),
#  ('Q to Broadway', 420),
#  ('Q to Canal St ; R to City Hall', 440),
#  ('Q to Church Ave', 381),
#  ('Q to Church Ave ; F', 456),
#  ('Q to DeKalb Ave ; F to York St ; M', 384),
#  ('Q to DeKalb Ave ; G to Hoyt & Schermerhorn', 411),
#  ('Q to DeKalb Ave ; G to Hoyt & Schermerhorn ; M to Court St', 417),
#  ('Q to Prospect Park', 370),
#  ('Q to Queensboro Plaza', 510),
#  ('Q to Queensboro Plaza ; E', 483),
#  ('Q to Queensboro Plaza ; R to Queens Plaza', 434),
#  ('Q1', 412),
#  ('Q10', 404),
#  ('Q100', 454),
#  ('Q101', 464),
#  ('Q102', 474),
#  ('Q103', 443),
#  ('Q104', 452),
#  ('Q11', 434),
#  ('Q110', 462),
#  ('Q111', 446),
#  ('Q112', 441),
#  ('Q113', 438),
#  ('Q12', 438),
#  ('Q13', 492),
#  ('Q15', 438),
#  ('Q15A', 438),
#  ('Q16', 445),
#  ('Q17', 495),
#  ('Q18', 434),
#  ('Q2', 419),
#  ('Q20A', 505),
#  ('Q20B', 481),
#  ('Q22', 435),
#  ('Q23', 482),
#  ('Q24', 434),
#  ('Q25', 473),
#  ('Q26', 438),
#  ('Q27', 481),
#  ('Q28', 492),
#  ('Q29', 423),
#  ('Q3', 456),
#  ('Q30', 507),
#  ('Q31', 504),
#  ('Q32', 466),
#  ('Q34', 441),
#  ('Q35', 519),
#  ('Q36', 466),
#  ('Q37', 422),
#  ('Q38', 456),
#  ('Q39', 466),
#  ('Q4', 479),
#  ('Q40', 417),
#  ('Q41', 440),
#  ('Q42', 582),
#  ('Q43', 432),
#  ('Q44', 354),
#  ('Q46', 451),
#  ('Q48', 441),
#  ('Q5', 456),
#  ('Q50', 392),
#  ('Q53', 437),
#  ('Q54', 408),
#  ('Q55', 394),
#  ('Q56', 434),
#  ('Q58', 410),
#  ('Q59', 418),
#  ('Q6', 446),
#  ('Q60', 479),
#  ('Q64', 529),
#  ('Q65', 464),
#  ('Q66', 461),
#  ('Q67', 466),
#  ('Q69', 444),
#  ('Q7', 407),
#  ('Q72', 423),
#  ('Q76', 488),
#  ('Q77', 413),
#  ('Q8', 443),
#  ('Q83', 449),
#  ('Q84', 507),
#  ('Q85', 485),
#  ('Q88', 508),
#  ('Q9', 462),
#  ('R', 442),
#  ('R to 14th St-Union Square ; L to 1st Ave', 451),
#  ('R to 14th St-Union Square ; L to 3rd Ave', 391),
#  ('R to 23rd St', 533),
#  ('R to 23rd St ; 2', 473),
#  ('R to 23rd St ; B', 563),
#  ('R to 23rd St ; L to 3rd Ave', 400),
#  ('R to 28th St', 423),
#  ('R to 34th St-Herald Square', 349),
#  ('R to 36th St ; N', 568),
#  ('R to 46th St', 449),
#  ('R to 49th St', 452),
#  ('R to 4th Ave - 9th St ; F', 406),
#  ('R to 57th St', 493),
#  ('R to 67th Ave', 497),
#  ('R to Atlantic Ave - Barclays Center ; A to Hoyt & Schermerhorn ; C to Lafayette Ave ; G to Fulton St',
#   421),
#  ('R to Borough Hall ; A', 417),
#  ('R to Canal St ; B', 438),
#  ('R to DeKalb Ave', 349),
#  ('R to DeKalb Ave ; C to Lafayette Ave ; D', 659),
#  ('R to Grand Ave - Newtown', 440),
#  ('R to Jay St-MetroTech', 384),
#  ('R to Jay St-MetroTech ; B', 411),
#  ('R to Lexington Ave-59 St ; 6', 441),
#  ('R to Lexington Ave-59 St ; 6 to 68th St - Hunter College ; F to Lexington Ave-63 St',
#   449),
#  ('R to Prince St', 452),
#  ('R to Queens Plaza', 401),
#  ('R to Queens Plaza ; F to 21st St - Queensbridge ; G to Court Square', 483),
#  ('R to Queens Plaza ; G to Court Square', 447),
#  ('R to Queens Plaza ; G to Court Square ; N', 510),
#  ('R to Rector St ; 1', 379),
#  ('R to Rector St ; 2', 426),
#  ('R to South Ferry ; 4', 423),
#  ('R to Steinway St ; N', 496),
#  ('R to Whitehall St-South Ferry ; 2', 471),
#  ('S to Beach 105th St-Seaside', 537),
#  ('S to Beach 98th St-Playland', 419),
#  ('S to Botanic Garden', 413),
#  ('S to Botanic Garden ; B', 370),
#  ('S to Franklin Ave', 481),
#  ('S to Franklin Ave ; G to Bedford-Nostrand', 443),
#  ('S to Grand Central - 42nd St ; 6 to 33rd St ; B', 349),
#  ('S to Park Place', 364),
#  ('S to Times Square-42nd St ; 4', 419),
#  ('S to Times Square-42nd St ; A to 42nd St-Port Authority Bus Terminal ; B',
#   490),
#  ('S1115', 612),
#  ('S40', 434),
#  ('S42', 432),
#  ('S44', 435),
#  ('S46', 434),
#  ('S48', 432),
#  ('S51', 422),
#  ('S52', 432),
#  ('S53', 452),
#  ('S54', 474),
#  ('S55', 486),
#  ('S56', 476),
#  ('S57', 490),
#  ('S59', 473),
#  ('S61', 451),
#  ('S62', 432),
#  ('S66', 442),
#  ('S74', 486),
#  ('S76', 486),
#  ('S78', 486),
#  ('S79-SBS', 505),
#  ('S89', 438),
#  ('SIR to Huguenot', 486),
#  ('SIR to New Dorp', 682),
#  ('SIR to St George', 432),
#  ('Z to 104th St-102nd St', 491),
#  ('Z to Bowery ; M to Delancey St-Essex St', 438),
#  ('Z to Broad St', 461),
#  ('Z to Broad St ; R to Cortlandt St', 489),
#  ('Z to Brooklyn Bridge - City Hall ; E to Park Place ; N', 440),
#  ('Z to Canal St ; B', 452),
#  ('Z to Delancey St-Essex St', 470),
#  ('Z to Elderts Lane-75th St', 371),
#  ('Z to Gates Ave', 372),
#  ('Z to Jamaica Center - Parsons / Archer', 660),
#  ('Z to Jamaica Center - Parsons / Archer ; F to Parsons Blvd', 417),
#  ('Z to Marcy Ave ; L to Bedford Ave', 395),
#  ('Z to Myrtle Ave', 355),
#  ('Z to Norwood Ave', 418)]
