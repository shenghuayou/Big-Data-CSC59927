# %% [markdown]
# # Homework 2 - Python Higher Order Functions
#
# ### DUE: 03/01/2017 before class at 9:30am
#
# In this homework, we will practice Python's higher order functions. Please note that you may only use higher order functions **without access to global variables**. Your expression should contain only **map()**, **filter()**, **sorted**, **reduce()** and your custom functions.
#
# You are required to turn in this notebook with all the parts filled in between <>. Your notebook must be named BDM\_HW2.ipynb
#
# We will be using only the citibike data (i.e. *citibike.csv*) for this homework.

# %%
import csv

# %% [markdown]
# ## Task 1 (2 points)
#
# We would like to write an HOF expression to count the total number of trip activities involved each station. For example, if a rider starts a trip at station A and ends at station B, each station A and B will receive +1 count for  the trip. The output must be tuples, each consisting of a station name and a total count. A portion of the expected output are included below.
#
# * **NOTE:** a suggested solution is given below to demonstrate the use of **sorted()**

# %%
def mapper1(row):
    return (row['start_station_name'], row['end_station_name'])

def reducer1(counts, pair):
    for p in pair:
        counts[p] = counts.get(p, 0)+1
    return counts

with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output1 = sorted(reduce(reducer1, map(mapper1, reader), {}).items())

output1[:10]
# Out:
# [('1 Ave & E 15 St', 795),
#  ('1 Ave & E 44 St', 219),
#  ('10 Ave & W 28 St', 422),
#  ('11 Ave & W 27 St', 354),
#  ('11 Ave & W 41 St', 461),
#  ('11 Ave & W 59 St', 242),
#  ('12 Ave & W 40 St', 217),
#  ('2 Ave & E 31 St', 588),
#  ('2 Ave & E 58 St', 125),
#  ('3 Ave & Schermerhorn St', 34)]

# %% [markdown]
# ## Task 2 (2 points)
#
# Next, we would like to do the same task as Task 1, but only keep the stations with more than 1000 trips involved. Please add your HOF expression below.

# %%
with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output2 = filter(lambda x: x[1]>1000,output1)
    
output2
# Out:
# [('8 Ave & W 31 St', 1065),
#  ('E 43 St & Vanderbilt Ave', 1003),
#  ('Lafayette St & E 8 St', 1013),
#  ('W 21 St & 6 Ave', 1057),
#  ('W 41 St & 8 Ave', 1095)]

# %% [markdown]
# ## Task 3 (2 points)
#
# We would like to count the number of trips taken between pairs of stations. Trips taken from station A to station B or  from station B to station A are both counted towards the station pair A and B. *Please note that the station pair should be identified by station names, as a tuple, and **in lexical order**, i.e. **(A,B)** instead of ~~(B,A)~~ in this case*. The output must be tuples, each consisting of the station pair identification and a count. A portion of the expected output are included below. Please provide your HOF expression.

# %%
def mapper3(row):
    if row['end_station_name'] < row['start_station_name']:
        return (row['end_station_name'], row['start_station_name'])
    else:
        return (row['start_station_name'], row['end_station_name'])

def reducer3(counts, pair):
    counts[pair] = counts.get(pair, 0)+1
    return counts

with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output3 = sorted(reduce(reducer3, map(mapper3, reader), {}).items())

output3[:10]
# Out:
# [(('1 Ave & E 15 St', '1 Ave & E 15 St'), 5),
#  (('1 Ave & E 15 St', '1 Ave & E 44 St'), 6),
#  (('1 Ave & E 15 St', '11 Ave & W 27 St'), 1),
#  (('1 Ave & E 15 St', '2 Ave & E 31 St'), 9),
#  (('1 Ave & E 15 St', '5 Ave & E 29 St'), 2),
#  (('1 Ave & E 15 St', '6 Ave & Broome St'), 3),
#  (('1 Ave & E 15 St', '6 Ave & Canal St'), 1),
#  (('1 Ave & E 15 St', '8 Ave & W 31 St'), 5),
#  (('1 Ave & E 15 St', '9 Ave & W 14 St'), 3),
#  (('1 Ave & E 15 St', '9 Ave & W 16 St'), 3)]

# %% [markdown]
# ## Task 4 (2 points)
#
# Next, we would like to futher process the output from Task 3 to determine the station popularity among all of the station pairs that have 35 or more trips. The popularity of station is calculated by how many times it appears on the list. In other words, we would like to first filter the station pairs to only those that have 35 or more trips. Then, among these pairs, we count how many time each station appears and report back the counts. The output will be tuples, each consisting of the station name and a count. The expected output are included below. As illustrated, *W 41 St & 8 Ave* station is the most "popular" with 4 appearances. Please provide your HOF expression below. You can use the output3 from the previous task.

# %%
def filter4(row):
    return row[1] >= 35


def reducer4(counts, pair):
    for p in pair[0]:
        counts[p] = counts.get(p, 0)+1
    return counts

output4 = sorted(reduce(reducer4,filter(filter4,output3),{}).items())
output4
# Out:
# [('10 Ave & W 28 St', 1),
#  ('11 Ave & W 27 St', 2),
#  ('11 Ave & W 41 St', 1),
#  ('8 Ave & W 31 St', 3),
#  ('8 Ave & W 33 St', 1),
#  ('9 Ave & W 22 St', 1),
#  ('Adelphi St & Myrtle Ave', 1),
#  ('DeKalb Ave & Hudson Ave', 1),
#  ('E 10 St & Avenue A', 1),
#  ('E 24 St & Park Ave S', 2),
#  ('E 27 St & 1 Ave', 1),
#  ('E 32 St & Park Ave', 1),
#  ('E 33 St & 2 Ave', 2),
#  ('E 43 St & Vanderbilt Ave', 2),
#  ('E 47 St & Park Ave', 1),
#  ('E 6 St & Avenue B', 1),
#  ('E 7 St & Avenue A', 1),
#  ('Lafayette St & E 8 St', 3),
#  ('Pershing Square North', 1),
#  ('Pershing Square South', 2),
#  ('Vesey Pl & River Terrace', 1),
#  ('W 17 St & 8 Ave', 1),
#  ('W 20 St & 11 Ave', 2),
#  ('W 21 St & 6 Ave', 1),
#  ('W 26 St & 8 Ave', 1),
#  ('W 31 St & 7 Ave', 2),
#  ('W 33 St & 7 Ave', 2),
#  ('W 41 St & 8 Ave', 4),
#  ('West Thames St', 1)]

# %% [markdown]
# ## Task 5 (2 points)
#
# In this task, you are asked to compute the station with the most riders started from, per each gender of the *'Subscriber'* user. Meaning, what was the station name with the highest number of bike pickups for female riders, for male riders and for unknown riders.
#
# The output will be a list of tuples, each includes a gender label (as indicated below) and another tuple consisting of a station name, and the total number of trips started at that station for that gender. The expected output are included below. Please provide your HOF expression below.
#
# The label mapping for the gender column in citibike.csv is: (Zero=**Unknown**; 1=**Male**; 2=**Female**)

# %%
def mapper4(row):
    return (row['start_station_name'], row['gender'])

def reducer4(counts, pair):
    for p in pair:
        counts[p] = counts.get(p, 0)+1
    return counts

with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output5 = map(mapper4,reader)

output5
# Out:
# [('8 Ave & W 31 St', '2'),
#  ('E 17 St & Broadway', '1'),
#  ('Grand Army Plaza & Central Park S', '2'),
#  ('6 Ave & Broome St', '2'),
#  ('Lawrence St & Willoughby St', '1'),
#  ('Willoughby Ave & Walworth St', '1'),
#  ('W 56 St & 6 Ave', '1'),
#  ('E 4 St & 2 Ave', '1'),
#  ('Washington Pl & Broadway', '2'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Greenwich Ave & 8 Ave', '2'),
#  ('Broadway & W 32 St', '2'),
#  ('Carmine St & 6 Ave', '2'),
#  ('E 11 St & 1 Ave', '2'),
#  ('Broadway & E 14 St', '1'),
#  ('Carmine St & 6 Ave', '1'),
#  ('E 9 St & Avenue C', '1'),
#  ('E 11 St & 1 Ave', '1'),
#  ('W 45 St & 6 Ave', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('E 3 St & 1 Ave', '1'),
#  ('E 48 St & 3 Ave', '1'),
#  ('W 56 St & 10 Ave', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('E 4 St & 2 Ave', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('Clinton St & Grand St', '1'),
#  ('Lafayette St & Jersey St', '2'),
#  ('1 Ave & E 15 St', '1'),
#  ('E 6 St & Avenue B', '1'),
#  ('E 20 St & 2 Ave', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('E 6 St & Avenue B', '1'),
#  ('Forsyth St & Broome St', '1'),
#  ('Shevchenko Pl & E 7 St', '1'),
#  ('Shevchenko Pl & E 7 St', '2'),
#  ('Shevchenko Pl & E 7 St', '1'),
#  ('W 13 St & 7 Ave', '1'),
#  ('Forsyth St & Broome St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('Broadway & W 49 St', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('Vesey Pl & River Terrace', '1'),
#  ('Fulton St & Rockwell Pl', '1'),
#  ('Watts St & Greenwich St', '1'),
#  ('W 18 St & 6 Ave', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('W 11 St & 6 Ave', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('Metropolitan Ave & Bedford Ave', '1'),
#  ('Broadway & W 41 St', '2'),
#  ('Greenwich Ave & Charles St', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('8 Ave & W 52 St', '1'),
#  ('W 13 St & 7 Ave', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Broadway & E 14 St', '1'),
#  ('Broadway & E 14 St', '2'),
#  ('E 11 St & 1 Ave', '1'),
#  ('2 Ave & E 58 St', '1'),
#  ('2 Ave & E 58 St', '2'),
#  ('9 Ave & W 18 St', '1'),
#  ('Washington Pl & Broadway', '1'),
#  ('Metropolitan Ave & Bedford Ave', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('E 14 St & Avenue B', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('W 52 St & 9 Ave', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('W 20 St & 7 Ave', '1'),
#  ('Broadway & W 32 St', '1'),
#  ('Park Ave & St Edwards St', '1'),
#  ('Broadway & W 49 St', '1'),
#  ('Greenwich Ave & 8 Ave', '2'),
#  ('W 22 St & 8 Ave', '0'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('E 2 St & Avenue C', '1'),
#  ('Liberty St & Broadway', '2'),
#  ('Allen St & Rivington St', '1'),
#  ('Lafayette Ave & Fort Greene Pl', '2'),
#  ('Allen St & Rivington St', '2'),
#  ('Ashland Pl & Hanson Pl', '1'),
#  ('Cleveland Pl & Spring St', '1'),
#  ('Peck Slip & Front St', '1'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('E 2 St & 2 Ave', '1'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('8 Ave & W 33 St', '2'),
#  ('MacDougal St & Prince St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Lafayette St & E 8 St', '2'),
#  ('W 22 St & 8 Ave', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('Watts St & Greenwich St', '1'),
#  ('Greenwich Ave & Charles St', '1'),
#  ('W 16 St & The High Line', '1'),
#  ('E 59 St & Sutton Pl', '2'),
#  ('Cleveland Pl & Spring St', '1'),
#  ('E 20 St & Park Ave', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('Washington St & Gansevoort St', '2'),
#  ('E 24 St & Park Ave S', '1'),
#  ('Duane St & Greenwich St', '1'),
#  ('E 19 St & 3 Ave', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Broadway & W 29 St', '1'),
#  ('DeKalb Ave & Hudson Ave', '2'),
#  ('Barclay St & Church St', '1'),
#  ('E 17 St & Broadway', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('9 Ave & W 45 St', '2'),
#  ('W Broadway & Spring St', '1'),
#  ('W 37 St & 5 Ave', '1'),
#  ('Allen St & Rivington St', '1'),
#  ('W 45 St & 8 Ave', '1'),
#  ('9 Ave & W 14 St', '1'),
#  ('Broadway & E 14 St', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('E 7 St & Avenue A', '1'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('Broadway & E 14 St', '1'),
#  ('E 47 St & 2 Ave', '1'),
#  ('W 52 St & 9 Ave', '1'),
#  ('E 11 St & 2 Ave', '2'),
#  ('Broadway & W 60 St', '1'),
#  ('Carmine St & 6 Ave', '1'),
#  ('11 Ave & W 41 St', '1'),
#  ('FDR Drive & E 35 St', '1'),
#  ('E 14 St & Avenue B', '1'),
#  ('E 13 St & Avenue A', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('Bank St & Washington St', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('Allen St & Rivington St', '1'),
#  ('Sullivan St & Washington Sq', '1'),
#  ('Wythe Ave & Metropolitan Ave', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('Broadway & W 24 St', '2'),
#  ('Allen St & Rivington St', '2'),
#  ('W 21 St & 6 Ave', '1'),
#  ('E 2 St & 2 Ave', '1'),
#  ('Washington Pl & Broadway', '1'),
#  ('Broadway & W 60 St', '1'),
#  ('Henry St & Atlantic Ave', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('9 Ave & W 14 St', '0'),
#  ('Broadway & W 36 St', '1'),
#  ('8 Ave & W 52 St', '1'),
#  ('E 6 St & Avenue B', '0'),
#  ('2 Ave & E 31 St', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('Broadway & E 14 St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('Cleveland Pl & Spring St', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('E 20 St & 2 Ave', '1'),
#  ('6 Ave & W 33 St', '1'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('11 Ave & W 41 St', '1'),
#  ('University Pl & E 14 St', '1'),
#  ('8 Ave & W 31 St', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('Lafayette St & Jersey St', '2'),
#  ('10 Ave & W 28 St', '1'),
#  ('Broadway & W 32 St', '1'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('W 41 St & 8 Ave', '2'),
#  ('E 6 St & Avenue D', '1'),
#  ('9 Ave & W 14 St', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('LaGuardia Pl & W 3 St', '2'),
#  ('E 24 St & Park Ave S', '1'),
#  ('6 Ave & W 33 St', '2'),
#  ('St Marks Pl & 1 Ave', '2'),
#  ('W 22 St & 8 Ave', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('E 12 St & 3 Ave', '1'),
#  ('Macon St & Nostrand Ave', '1'),
#  ('E 5 St & Avenue C', '1'),
#  ('9 Ave & W 18 St', '1'),
#  ('9 Ave & W 45 St', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('E 14 St & Avenue B', '1'),
#  ('W 52 St & 5 Ave', '1'),
#  ('Metropolitan Ave & Bedford Ave', '1'),
#  ('MacDougal St & Washington Sq', '1'),
#  ('E 12 St & 3 Ave', '1'),
#  ('Mott St & Prince St', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('W 20 St & 8 Ave', '1'),
#  ('9 Ave & W 14 St', '1'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('E 27 St & 1 Ave', '1'),
#  ('E 2 St & 2 Ave', '1'),
#  ('E 39 St & 2 Ave', '2'),
#  ('Broadway & W 39 St', '1'),
#  ('Sullivan St & Washington Sq', '1'),
#  ('9 Ave & W 18 St', '1'),
#  ('Grand Army Plaza & Central Park S', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('Washington Pl & 6 Ave', '1'),
#  ('W 20 St & 8 Ave', '0'),
#  ('E 25 St & 1 Ave', '1'),
#  ('Liberty St & Broadway', '1'),
#  ('LaGuardia Pl & W 3 St', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('W 45 St & 6 Ave', '0'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('W 39 St & 9 Ave', '1'),
#  ('E 31 St & 3 Ave', '1'),
#  ('Broadway & W 36 St', '1'),
#  ('E 2 St & Avenue C', '1'),
#  ('W 38 St & 8 Ave', '2'),
#  ('W 31 St & 7 Ave', '1'),
#  ('DeKalb Ave & Vanderbilt Ave', '2'),
#  ('Clinton St & Grand St', '1'),
#  ('W 41 St & 8 Ave', '0'),
#  ('Broadway & E 14 St', '1'),
#  ('E 47 St & 2 Ave', '2'),
#  ('10 Ave & W 28 St', '2'),
#  ('Clermont Ave & Park Ave', '1'),
#  ('W 22 St & 10 Ave', '1'),
#  ('E 2 St & Avenue B', '1'),
#  ('MacDougal St & Washington Sq', '1'),
#  ('6 Ave & Canal St', '1'),
#  ('Forsyth St & Broome St', '0'),
#  ('8 Ave & W 33 St', '1'),
#  ('Lexington Ave & E 24 St', '2'),
#  ('Hancock St & Bedford Ave', '1'),
#  ('Ashland Pl & Hanson Pl', '1'),
#  ('W 26 St & 8 Ave', '1'),
#  ('W 26 St & 8 Ave', '1'),
#  ('2 Ave & E 31 St', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('W 33 St & 7 Ave', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('W 39 St & 9 Ave', '1'),
#  ('Clinton St & Joralemon St', '1'),
#  ('Pike St & E Broadway', '0'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('12 Ave & W 40 St', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('E 2 St & Avenue B', '1'),
#  ('E 33 St & 2 Ave', '1'),
#  ('Watts St & Greenwich St', '1'),
#  ('W 37 St & 10 Ave', '1'),
#  ('W 11 St & 6 Ave', '1'),
#  ('E 2 St & Avenue B', '1'),
#  ('E 31 St & 3 Ave', '1'),
#  ('E 39 St & 2 Ave', '1'),
#  ('Rivington St & Ridge St', '0'),
#  ('E 19 St & 3 Ave', '1'),
#  ('11 Ave & W 59 St', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('Broadway & W 55 St', '1'),
#  ('E 6 St & Avenue D', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('Clinton Ave & Myrtle Ave', '1'),
#  ('E 33 St & 2 Ave', '1'),
#  ('E 5 St & Avenue C', '1'),
#  ('E 40 St & 5 Ave', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Mott St & Prince St', '1'),
#  ('Franklin St & W Broadway', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('E 6 St & Avenue B', '2'),
#  ('W 41 St & 8 Ave', '1'),
#  ('E 27 St & 1 Ave', '2'),
#  ('Madison St & Clinton St', '1'),
#  ('Broadway & W 51 St', '1'),
#  ('Henry St & Grand St', '2'),
#  ('E 5 St & Avenue C', '1'),
#  ('E 20 St & 2 Ave', '1'),
#  ('Clinton Ave & Myrtle Ave', '1'),
#  ('South End Ave & Liberty St', '2'),
#  ('E 33 St & 2 Ave', '1'),
#  ('Clinton Ave & Myrtle Ave', '1'),
#  ('Clark St & Henry St', '1'),
#  ('E 27 St & 1 Ave', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('Clinton Ave & Myrtle Ave', '2'),
#  ('1 Ave & E 15 St', '1'),
#  ('8 Ave & W 31 St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Broadway & W 53 St', '1'),
#  ('W 11 St & 6 Ave', '2'),
#  ('W 22 St & 8 Ave', '1'),
#  ('11 Ave & W 27 St', '1'),
#  ('W 17 St & 8 Ave', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('Lexington Ave & E 24 St', '2'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Pearl St & Hanover Square', '1'),
#  ('E 5 St & Avenue C', '1'),
#  ('Pike St & Monroe St', '2'),
#  ('E 51 St & Lexington Ave', '1'),
#  ('Hicks St & Montague St', '1'),
#  ('E 9 St & Avenue C', '1'),
#  ('W 26 St & 8 Ave', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('9 Ave & W 18 St', '1'),
#  ('E 20 St & Park Ave', '1'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('Jay St & Tech Pl', '1'),
#  ('Monroe St & Bedford Ave', '1'),
#  ('E 20 St & FDR Drive', '2'),
#  ('E 59 St & Sutton Pl', '1'),
#  ('W 34 St & 11 Ave', '1'),
#  ('Front St & Maiden Ln', '1'),
#  ('W 37 St & 10 Ave', '1'),
#  ('W 37 St & 10 Ave', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('Division St & Bowery', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('Leonard St & Church St', '1'),
#  ('Leonard St & Church St', '2'),
#  ('E 4 St & 2 Ave', '1'),
#  ('Forsyth St & Canal St', '1'),
#  ('MacDougal St & Washington Sq', '1'),
#  ('MacDougal St & Washington Sq', '2'),
#  ('1 Ave & E 15 St', '2'),
#  ('Henry St & Grand St', '1'),
#  ('Clinton St & Grand St', '1'),
#  ('W 54 St & 9 Ave', '1'),
#  ('Barrow St & Hudson St', '1'),
#  ('E 23 St & 1 Ave', '2'),
#  ('Broadway & E 14 St', '1'),
#  ('Barclay St & Church St', '2'),
#  ('W 15 St & 7 Ave', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('Bank St & Hudson St', '1'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('Washington Square E', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('Washington St & Gansevoort St', '2'),
#  ('Broadway & E 14 St', '1'),
#  ('9 Ave & W 22 St', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('W 56 St & 6 Ave', '1'),
#  ('W 52 St & 9 Ave', '1'),
#  ('2 Ave & E 31 St', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('E 23 St & 1 Ave', '1'),
#  ('E 33 St & 2 Ave', '2'),
#  ('8 Ave & W 31 St', '1'),
#  ('11 Ave & W 59 St', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('11 Ave & W 27 St', '2'),
#  ('11 Ave & W 27 St', '2'),
#  ('Washington Pl & Broadway', '1'),
#  ('E 12 St & 3 Ave', '2'),
#  ('Bank St & Hudson St', '1'),
#  ('Barclay St & Church St', '2'),
#  ('E 7 St & Avenue A', '1'),
#  ('W 20 St & 11 Ave', '1'),
#  ('Cherry St', '1'),
#  ('Mott St & Prince St', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('Mercer St & Bleecker St', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('Clark St & Henry St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('W 52 St & 11 Ave', '2'),
#  ('E 20 St & 2 Ave', '1'),
#  ('8 Ave & W 52 St', '1'),
#  ('E 30 St & Park Ave S', '1'),
#  ('W 39 St & 9 Ave', '1'),
#  ('Broadway & W 55 St', '1'),
#  ('E 33 St & 5 Ave', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Broadway & W 36 St', '1'),
#  ('W 22 St & 10 Ave', '1'),
#  ('E 23 St & 1 Ave', '1'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('E 20 St & Park Ave', '1'),
#  ('E 2 St & Avenue C', '2'),
#  ('W 11 St & 6 Ave', '2'),
#  ('W 11 St & 6 Ave', '1'),
#  ('Lafayette Ave & Fort Greene Pl', '1'),
#  ('8 Ave & W 31 St', '1'),
#  ('Front St & Washington St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('W 17 St & 8 Ave', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('Monroe St & Classon Ave', '1'),
#  ('W 27 St & 7 Ave', '1'),
#  ('E 43 St & Vanderbilt Ave', '1'),
#  ('E 20 St & Park Ave', '2'),
#  ('Stanton St & Chrystie St', '1'),
#  ('Broadway & E 14 St', '1'),
#  ('E 11 St & Broadway', '2'),
#  ('E 43 St & Vanderbilt Ave', '1'),
#  ('Adelphi St & Myrtle Ave', '1'),
#  ('W Broadway & Spring St', '2'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('Spruce St & Nassau St', '1'),
#  ('Greenwich St & N Moore St', '1'),
#  ('E 16 St & 5 Ave', '1'),
#  ('Canal St & Rutgers St', '2'),
#  ('W 34 St & 11 Ave', '1'),
#  ('E 6 St & Avenue D', '1'),
#  ('Broadway & W 29 St', '1'),
#  ('Dean St & 4 Ave', '1'),
#  ('Hudson St & Reade St', '2'),
#  ('DeKalb Ave & Hudson Ave', '1'),
#  ('E 30 St & Park Ave S', '1'),
#  ('E 20 St & Park Ave', '1'),
#  ('W 21 St & 6 Ave', '2'),
#  ('1 Ave & E 15 St', '2'),
#  ('E 39 St & 3 Ave', '2'),
#  ('Allen St & Rivington St', '1'),
#  ('E 17 St & Broadway', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('E 39 St & 2 Ave', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('Front St & Washington St', '1'),
#  ('W 21 St & 6 Ave', '2'),
#  ('E 2 St & Avenue C', '2'),
#  ('Fulton St & William St', '1'),
#  ('Clinton St & Grand St', '1'),
#  ('W 49 St & 8 Ave', '0'),
#  ('W 49 St & 8 Ave', '0'),
#  ('Bialystoker Pl & Delancey St', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('Barrow St & Hudson St', '1'),
#  ('E 40 St & 5 Ave', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('Flushing Ave & Carlton Ave', '1'),
#  ('W 39 St & 9 Ave', '1'),
#  ('W 49 St & 8 Ave', '0'),
#  ('E 25 St & 1 Ave', '2'),
#  ('Barrow St & Hudson St', '1'),
#  ('Bedford Ave & S 9th St', '1'),
#  ('Allen St & Hester St', '1'),
#  ('Duffield St & Willoughby St', '1'),
#  ('Madison St & Clinton St', '2'),
#  ('W 17 St & 8 Ave', '2'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('Henry St & Atlantic Ave', '1'),
#  ('Madison St & Montgomery St', '2'),
#  ('2 Ave & E 31 St', '1'),
#  ('Broadway & W 29 St', '1'),
#  ('E 10 St & Avenue A', '2'),
#  ('1 Ave & E 15 St', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('W 21 St & 6 Ave', '2'),
#  ('W 17 St & 8 Ave', '1'),
#  ('Henry St & Atlantic Ave', '1'),
#  ('E 2 St & Avenue C', '2'),
#  ('E 23 St & 1 Ave', '2'),
#  ('E 16 St & Irving Pl', '1'),
#  ('W 22 St & 8 Ave', '1'),
#  ('Clinton St & Tillary St', '1'),
#  ('W 41 St & 8 Ave', '0'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('Sullivan St & Washington Sq', '1'),
#  ('Hicks St & Montague St', '1'),
#  ('Allen St & E Houston St', '2'),
#  ('E 2 St & Avenue B', '2'),
#  ('E 2 St & 2 Ave', '2'),
#  ('9 Ave & W 45 St', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('Madison St & Montgomery St', '2'),
#  ('E 37 St & Lexington Ave', '2'),
#  ('LaGuardia Pl & W 3 St', '2'),
#  ('E 32 St & Park Ave', '2'),
#  ('9 Ave & W 22 St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('W 4 St & 7 Ave S', '2'),
#  ('Joralemon St & Adams St', '1'),
#  ('9 Ave & W 22 St', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('E 2 St & 2 Ave', '2'),
#  ('E 11 St & 2 Ave', '1'),
#  ('Willoughby Ave & Hall St', '2'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('E 7 St & Avenue A', '1'),
#  ('Washington St & Gansevoort St', '1'),
#  ('Bank St & Hudson St', '1'),
#  ('Henry St & Atlantic Ave', '1'),
#  ('E 11 St & 2 Ave', '1'),
#  ('LaGuardia Pl & W 3 St', '2'),
#  ('Avenue D & E 8 St', '1'),
#  ('Bialystoker Pl & Delancey St', '2'),
#  ('Madison St & Montgomery St', '1'),
#  ('E 2 St & Avenue B', '1'),
#  ('W 56 St & 6 Ave', '2'),
#  ('E 13 St & Avenue A', '1'),
#  ('Greenwich St & Warren St', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Clark St & Henry St', '1'),
#  ('W 51 St & 6 Ave', '0'),
#  ('E 33 St & 2 Ave', '1'),
#  ('Washington Pl & 6 Ave', '2'),
#  ('Catherine St & Monroe St', '2'),
#  ('W 21 St & 6 Ave', '1'),
#  ('E 47 St & 2 Ave', '1'),
#  ('E 12 St & 3 Ave', '1'),
#  ('Sullivan St & Washington Sq', '1'),
#  ('E 39 St & 2 Ave', '1'),
#  ('St James Pl & Oliver St', '2'),
#  ('Henry St & Grand St', '1'),
#  ('W 41 St & 8 Ave', '2'),
#  ('E 33 St & 2 Ave', '1'),
#  ('E 30 St & Park Ave S', '2'),
#  ('3 Ave & Schermerhorn St', '1'),
#  ('Carlton Ave & Park Ave', '1'),
#  ('1 Ave & E 44 St', '2'),
#  ('E 14 St & Avenue B', '1'),
#  ('Lexington Ave & E 24 St', '2'),
#  ('Johnson St & Gold St', '2'),
#  ('Canal St & Rutgers St', '2'),
#  ('11 Ave & W 27 St', '2'),
#  ('2 Ave & E 31 St', '1'),
#  ('E 3 St & 1 Ave', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('E 6 St & Avenue B', '1'),
#  ('E 39 St & 2 Ave', '2'),
#  ('W 45 St & 8 Ave', '1'),
#  ('Bialystoker Pl & Delancey St', '1'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('Ashland Pl & Hanson Pl', '0'),
#  ('Washington Square E', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('Barrow St & Hudson St', '2'),
#  ('E 2 St & Avenue B', '1'),
#  ('Peck Slip & Front St', '1'),
#  ('Washington Ave & Park Ave', '2'),
#  ('E 59 St & Sutton Pl', '1'),
#  ('Greenwich St & N Moore St', '2'),
#  ('Avenue D & E 8 St', '1'),
#  ('Avenue D & E 8 St', '1'),
#  ('E 31 St & 3 Ave', '1'),
#  ('W 26 St & 8 Ave', '1'),
#  ('E 30 St & Park Ave S', '1'),
#  ('Clinton St & Tillary St', '1'),
#  ('E 11 St & 1 Ave', '1'),
#  ('Division St & Bowery', '1'),
#  ('Henry St & Grand St', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('W 26 St & 10 Ave', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('Broadway & W 49 St', '1'),
#  ('Hicks St & Montague St', '1'),
#  ('Rivington St & Chrystie St', '1'),
#  ('Clinton St & Tillary St', '1'),
#  ('State St & Smith St', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('Avenue D & E 3 St', '2'),
#  ('W 49 St & 8 Ave', '2'),
#  ('Stanton St & Mangin St', '1'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('Spruce St & Nassau St', '1'),
#  ('E 30 St & Park Ave S', '0'),
#  ('E 20 St & Park Ave', '1'),
#  ('8 Ave & W 31 St', '2'),
#  ('W 53 St & 10 Ave', '1'),
#  ('Stanton St & Chrystie St', '1'),
#  ('Lafayette Ave & Classon Ave', '1'),
#  ('Lexington Ave & E 24 St', '2'),
#  ('W 15 St & 7 Ave', '2'),
#  ('Washington Square E', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('Broadway & W 24 St', '2'),
#  ('W 22 St & 8 Ave', '2'),
#  ('Lexington Ave & E 24 St', '2'),
#  ('8 Ave & W 31 St', '1'),
#  ('E 23 St & 1 Ave', '1'),
#  ('6 Ave & W 33 St', '1'),
#  ('E 39 St & 3 Ave', '1'),
#  ('W 52 St & 9 Ave', '1'),
#  ('E 11 St & 2 Ave', '2'),
#  ('Lafayette St & E 8 St', '1'),
#  ('Adelphi St & Myrtle Ave', '2'),
#  ('St Marks Pl & 1 Ave', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 27 St & 7 Ave', '2'),
#  ('E 10 St & Avenue A', '1'),
#  ('E 12 St & 3 Ave', '1'),
#  ('E 14 St & Avenue B', '1'),
#  ('Columbia St & Rivington St', '2'),
#  ('W Broadway & Spring St', '2'),
#  ('W 20 St & 8 Ave', '1'),
#  ('E 20 St & FDR Drive', '2'),
#  ('E 14 St & Avenue B', '1'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('Hicks St & Montague St', '2'),
#  ('W 20 St & 11 Ave', '1'),
#  ('Warren St & Church St', '1'),
#  ('Great Jones St', '1'),
#  ('E 30 St & Park Ave S', '2'),
#  ('2 Ave & E 58 St', '1'),
#  ('E 30 St & Park Ave S', '1'),
#  ('Grand Army Plaza & Central Park S', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('Cherry St', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 53 St & 10 Ave', '1'),
#  ('E 55 St & Lexington Ave', '1'),
#  ('E 58 St & 3 Ave', '1'),
#  ('State St & Smith St', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('E 11 St & 2 Ave', '2'),
#  ('E 33 St & 5 Ave', '1'),
#  ('W 43 St & 10 Ave', '2'),
#  ('E 23 St & 1 Ave', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('W 13 St & 6 Ave', '2'),
#  ('W 49 St & 8 Ave', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('Rivington St & Ridge St', '1'),
#  ('E 17 St & Broadway', '1'),
#  ('Avenue D & E 8 St', '1'),
#  ('Grand Army Plaza & Central Park S', '1'),
#  ('Washington Square E', '1'),
#  ('W 4 St & 7 Ave S', '2'),
#  ('W 22 St & 8 Ave', '1'),
#  ('Allen St & E Houston St', '2'),
#  ('Stanton St & Chrystie St', '2'),
#  ('W 52 St & 11 Ave', '2'),
#  ('W 15 St & 7 Ave', '1'),
#  ('E 56 St & 3 Ave', '1'),
#  ('Grand Army Plaza & Central Park S', '2'),
#  ('Lexington Ave & Classon Ave', '1'),
#  ('E 5 St & Avenue C', '1'),
#  ('E 40 St & 5 Ave', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 24 St & 7 Ave', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('E 3 St & 1 Ave', '1'),
#  ('Little West St & 1 Pl', '2'),
#  ('W 22 St & 10 Ave', '1'),
#  ('Fulton St & Grand Ave', '1'),
#  ('E 6 St & Avenue B', '2'),
#  ('Henry St & Grand St', '2'),
#  ('Duane St & Greenwich St', '1'),
#  ('E 32 St & Park Ave', '1'),
#  ('E 55 St & 2 Ave', '1'),
#  ('W 20 St & 8 Ave', '1'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('FDR Drive & E 35 St', '1'),
#  ('FDR Drive & E 35 St', '1'),
#  ('Fulton St & Rockwell Pl', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Pike St & Monroe St', '1'),
#  ('W 22 St & 8 Ave', '1'),
#  ('8 Ave & W 52 St', '1'),
#  ('9 Ave & W 18 St', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('9 Ave & W 18 St', '1'),
#  ('E 51 St & Lexington Ave', '1'),
#  ('Catherine St & Monroe St', '1'),
#  ('Grand Army Plaza & Central Park S', '1'),
#  ('Washington Square E', '1'),
#  ('Peck Slip & Front St', '2'),
#  ('W 26 St & 10 Ave', '1'),
#  ('Pike St & Monroe St', '1'),
#  ('E 20 St & Park Ave', '1'),
#  ('Henry St & Grand St', '1'),
#  ('E 25 St & 1 Ave', '1'),
#  ('E 2 St & Avenue B', '2'),
#  ('E 19 St & 3 Ave', '1'),
#  ('11 Ave & W 41 St', '1'),
#  ('E 20 St & Park Ave', '2'),
#  ('Hicks St & Montague St', '2'),
#  ('Little West St & 1 Pl', '1'),
#  ('Washington Park', '2'),
#  ('W 20 St & 11 Ave', '1'),
#  ('E 6 St & Avenue B', '1'),
#  ('Madison St & Clinton St', '2'),
#  ('E 17 St & Broadway', '1'),
#  ('W 26 St & 8 Ave', '1'),
#  ('Broadway & W 32 St', '1'),
#  ('Division St & Bowery', '1'),
#  ('DeKalb Ave & Hudson Ave', '2'),
#  ('DeKalb Ave & Hudson Ave', '1'),
#  ('S Portland Ave & Hanson Pl', '1'),
#  ('Adelphi St & Myrtle Ave', '1'),
#  ('E 2 St & 2 Ave', '1'),
#  ('Pike St & Monroe St', '1'),
#  ('Henry St & Grand St', '1'),
#  ('W 20 St & 8 Ave', '2'),
#  ('Myrtle Ave & St Edwards St', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('Broadway & W 58 St', '2'),
#  ('2 Ave & E 31 St', '1'),
#  ('Stanton St & Chrystie St', '1'),
#  ('E 39 St & 3 Ave', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('E 25 St & 1 Ave', '2'),
#  ('W 24 St & 7 Ave', '2'),
#  ('Stanton St & Chrystie St', '1'),
#  ('W 17 St & 8 Ave', '1'),
#  ('E 43 St & Vanderbilt Ave', '1'),
#  ('Allen St & Hester St', '1'),
#  ('MacDougal St & Prince St', '0'),
#  ('E 11 St & 2 Ave', '2'),
#  ('Metropolitan Ave & Bedford Ave', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('Broadway & W 58 St', '2'),
#  ('W 22 St & 10 Ave', '1'),
#  ('Allen St & Rivington St', '1'),
#  ('W 26 St & 10 Ave', '1'),
#  ('Forsyth St & Canal St', '2'),
#  ('12 Ave & W 40 St', '1'),
#  ('Mott St & Prince St', '1'),
#  ('6 Ave & W 33 St', '0'),
#  ('MacDougal St & Prince St', '2'),
#  ('Clinton St & Grand St', '2'),
#  ('1 Ave & E 15 St', '1'),
#  ('9 Ave & W 22 St', '1'),
#  ('E 9 St & Avenue C', '1'),
#  ('W 20 St & 7 Ave', '2'),
#  ('Broadway & W 29 St', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('MacDougal St & Prince St', '1'),
#  ('Lexington Ave & E 24 St', '1'),
#  ('Suffolk St & Stanton St', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('E 16 St & Irving Pl', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('Broadway & W 53 St', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('Broadway & E 22 St', '1'),
#  ('Suffolk St & Stanton St', '1'),
#  ('E 56 St & Madison Ave', '1'),
#  ('E 10 St & 5 Ave', '1'),
#  ('E 20 St & 2 Ave', '2'),
#  ('E 25 St & 2 Ave', '2'),
#  ('W 25 St & 6 Ave', '1'),
#  ('Clinton St & Grand St', '1'),
#  ('Clinton St & Grand St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Broadway & E 14 St', '2'),
#  ('Fulton St & Waverly Ave', '2'),
#  ('E 2 St & Avenue B', '1'),
#  ('E 13 St & Avenue A', '1'),
#  ('W 13 St & 7 Ave', '1'),
#  ('W 25 St & 6 Ave', '1'),
#  ('E 2 St & 2 Ave', '2'),
#  ('E 13 St & Avenue A', '1'),
#  ('W 21 St & 6 Ave', '2'),
#  ('W 20 St & 8 Ave', '1'),
#  ('Avenue D & E 8 St', '2'),
#  ('E 2 St & Avenue B', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('Greenwich St & Warren St', '2'),
#  ('Great Jones St', '1'),
#  ('Warren St & Church St', '1'),
#  ('Broadway & W 41 St', '2'),
#  ('E 6 St & Avenue B', '2'),
#  ('W 42 St & 8 Ave', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('W 39 St & 9 Ave', '1'),
#  ('W 49 St & 8 Ave', '1'),
#  ('Bayard St & Baxter St', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('Forsyth St & Broome St', '1'),
#  ('Willoughby Ave & Walworth St', '1'),
#  ('W 18 St & 6 Ave', '1'),
#  ('1 Ave & E 15 St', '2'),
#  ('E 17 St & Broadway', '1'),
#  ('W 26 St & 10 Ave', '1'),
#  ('West St & Chambers St', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('Harrison St & Hudson St', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('Centre St & Worth St', '0'),
#  ('E 17 St & Broadway', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('W 20 St & 11 Ave', '1'),
#  ('W 42 St & 8 Ave', '1'),
#  ('Shevchenko Pl & E 7 St', '2'),
#  ('Concord St & Bridge St', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('Madison St & Montgomery St', '1'),
#  ('Grand St & Greene St', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('Bayard St & Baxter St', '2'),
#  ('W 24 St & 7 Ave', '1'),
#  ('Stanton St & Chrystie St', '1'),
#  ('E 19 St & 3 Ave', '2'),
#  ('Barclay St & Church St', '1'),
#  ('Stanton St & Chrystie St', '1'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 26 St & 10 Ave', '1'),
#  ('9 Ave & W 22 St', '1'),
#  ('Little West St & 1 Pl', '2'),
#  ('Greenwich Ave & Charles St', '1'),
#  ('Little West St & 1 Pl', '1'),
#  ('Bank St & Hudson St', '1'),
#  ('E 10 St & Avenue A', '2'),
#  ('Mott St & Prince St', '2'),
#  ('Cherry St', '2'),
#  ('Bialystoker Pl & Delancey St', '2'),
#  ('Lafayette St & Jersey St', '1'),
#  ('Duane St & Greenwich St', '1'),
#  ('S 5 Pl & S 4 St', '1'),
#  ('W 29 St & 9 Ave', '1'),
#  ('Forsyth St & Broome St', '1'),
#  ('Forsyth St & Canal St', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('Canal St & Rutgers St', '1'),
#  ('Suffolk St & Stanton St', '2'),
#  ('Spruce St & Nassau St', '2'),
#  ('W 22 St & 8 Ave', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Broadway & W 39 St', '1'),
#  ('Central Park S & 6 Ave', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('W 46 St & 11 Ave', '1'),
#  ('E 10 St & 5 Ave', '1'),
#  ('E 39 St & 2 Ave', '2'),
#  ('W 20 St & 7 Ave', '1'),
#  ('E 47 St & 2 Ave', '1'),
#  ('W 13 St & 7 Ave', '1'),
#  ('W 26 St & 10 Ave', '1'),
#  ('LaGuardia Pl & W 3 St', '2'),
#  ('W 47 St & 10 Ave', '1'),
#  ('W 25 St & 6 Ave', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('Broadway & W 55 St', '1'),
#  ('W 26 St & 10 Ave', '2'),
#  ('E 55 St & Lexington Ave', '1'),
#  ('E 30 St & Park Ave S', '2'),
#  ('Pike St & E Broadway', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('Bayard St & Baxter St', '1'),
#  ('E 19 St & 3 Ave', '1'),
#  ('Mott St & Prince St', '2'),
#  ('Greenwich St & Warren St', '2'),
#  ('E 14 St & Avenue B', '2'),
#  ('11 Ave & W 41 St', '1'),
#  ('E 17 St & Broadway', '1'),
#  ('West Thames St', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('E 47 St & 1 Ave', '2'),
#  ('John St & William St', '1'),
#  ('Allen St & Hester St', '2'),
#  ('Greenwich Ave & 8 Ave', '2'),
#  ('E 39 St & 3 Ave', '2'),
#  ('W 21 St & 6 Ave', '1'),
#  ('W 41 St & 8 Ave', '1'),
#  ('Leonard St & Church St', '1'),
#  ('Cleveland Pl & Spring St', '1'),
#  ('Lafayette St & Jersey St', '1'),
#  ('W 29 St & 9 Ave', '1'),
#  ('W 4 St & 7 Ave S', '1'),
#  ('MacDougal St & Washington Sq', '2'),
#  ('South St & Whitehall St', '1'),
#  ('Monroe St & Bedford Ave', '1'),
#  ('Clinton St & Grand St', '2'),
#  ('Broadway & W 55 St', '2'),
#  ('Columbia St & Rivington St', '2'),
#  ('Grand Army Plaza & Central Park S', '1'),
#  ('E 10 St & Avenue A', '1'),
#  ('W 16 St & The High Line', '1'),
#  ('E 25 St & 2 Ave', '1'),
#  ('E 47 St & 1 Ave', '2'),
#  ('1 Ave & E 15 St', '2'),
#  ('E 2 St & 2 Ave', '1'),
#  ('W 21 St & 6 Ave', '2'),
#  ('W 20 St & 7 Ave', '1'),
#  ('W 27 St & 7 Ave', '1'),
#  ('LaGuardia Pl & W 3 St', '1'),
#  ('W 11 St & 6 Ave', '2'),
#  ('W 43 St & 10 Ave', '1'),
#  ('Allen St & E Houston St', '1'),
#  ('W 24 St & 7 Ave', '1'),
#  ('Greenwich Ave & 8 Ave', '1'),
#  ('LaGuardia Pl & W 3 St', '1'),
#  ('Pike St & E Broadway', '1'),
#  ('E 2 St & Avenue B', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('Henry St & Atlantic Ave', '1'),
#  ('Henry St & Grand St', '1'),
#  ('Allen St & Rivington St', '2'),
#  ('W 43 St & 10 Ave', '1'),
#  ('W 43 St & 10 Ave', '1'),
#  ('Cliff St & Fulton St', '1'),
#  ('Broadway & W 29 St', '1'),
#  ('E 3 St & 1 Ave', '2'),
#  ('E 33 St & 2 Ave', '1'),
#  ('E 12 St & 3 Ave', '1'),
#  ('W 43 St & 10 Ave', '2'),
#  ('E 10 St & 5 Ave', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('Bank St & Hudson St', '1'),
#  ('E 17 St & Broadway', '1'),
#  ('John St & William St', '1'),
#  ('9 Ave & W 18 St', '2'),
#  ('E 9 St & Avenue C', '2'),
#  ('MacDougal St & Prince St', '1'),
#  ('E 10 St & 5 Ave', '2'),
#  ('W 11 St & 6 Ave', '1'),
#  ('St James Pl & Pearl St', '1'),
#  ('Broadway & W 24 St', '0'),
#  ('W 37 St & 10 Ave', '1'),
#  ('W 18 St & 6 Ave', '1'),
#  ('Avenue D & E 3 St', '1'),
#  ('Clermont Ave & Park Ave', '1'),
#  ('W 20 St & 11 Ave', '1'),
#  ('Lafayette St & E 8 St', '1'),
#  ('Stanton St & Mangin St', '2'),
#  ('Clinton Ave & Myrtle Ave', '1'),
#  ('E 7 St & Avenue A', '2'),
#  ('E 39 St & 2 Ave', '2'),
#  ('Columbia St & Rivington St', '1'),
#  ('Wythe Ave & Metropolitan Ave', '1'),
#  ('Columbia St & Rivington St', '2'),
#  ('W 37 St & 10 Ave', '2'),
#  ('Broadway & W 58 St', '1'),
#  ('Columbia St & Rivington St', '2'),
#  ('Pike St & Monroe St', '2'),
#  ('E 3 St & 1 Ave', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('W 18 St & 6 Ave', '1'),
#  ('W 18 St & 6 Ave', '2'),
#  ('E 7 St & Avenue A', '1'),
#  ('Washington St & Gansevoort St', '1'),
#  ('Broadway & W 55 St', '1'),
#  ('E 27 St & 1 Ave', '1'),
#  ('W 13 St & 6 Ave', '1'),
#  ('Barrow St & Hudson St', '1'),
#  ('E 40 St & 5 Ave', '1'),
#  ('W 45 St & 8 Ave', '1'),
#  ('8 Ave & W 33 St', '1'),
#  ('Broadway & W 58 St', '1'),
#  ('West St & Chambers St', '2'),
#  ('E 27 St & 1 Ave', '1'),
#  ('E 14 St & Avenue B', '1'),
#  ('West St & Chambers St', '2'),
#  ('Jay St & Tech Pl', '1'),
#  ('W 17 St & 8 Ave', '1'),
#  ('Emerson Pl & Myrtle Ave', '1'),
#  ('E 13 St & Avenue A', '1'),
#  ('Mott St & Prince St', '2'),
#  ('Howard St & Centre St', '1'),
#  ('E 27 St & 1 Ave', '1'),
#  ('Cleveland Pl & Spring St', '1'),
#  ('John St & William St', '2'),
#  ('W 27 St & 7 Ave', '1'),
#  ('1 Ave & E 15 St', '1'),
#  ('Maiden Ln & Pearl St', '2'),
#  ('W 22 St & 10 Ave', '1'),
#  ('6 Ave & Canal St', '1'),
#  ('W 22 St & 8 Ave', '1'),
#  ('W 20 St & 11 Ave', '1'),
#  ('W 20 St & 11 Ave', '1'),
#  ('Lawrence St & Willoughby St', '2'),
#  ('Pearl St & Hanover Square', '1'),
#  ('Division St & Bowery', '2'),
#  ('Broadway & W 53 St', '1'),
#  ('E 11 St & 1 Ave', '1'),
#  ('E 56 St & 3 Ave', '1'),
#  ('Washington Square E', '1'),
#  ('W 27 St & 7 Ave', '2'),
#  ('Division St & Bowery', '2'),
#  ('W 49 St & 8 Ave', '1'),
#  ('Broadway & W 24 St', '1'),
#  ('Avenue D & E 12 St', '1'),
#  ('E 23 St & 1 Ave', '1'),
#  ('Water - Whitehall Plaza', '0'),
#  ('St Marks Pl & 2 Ave', '1'),
#  ('E 20 St & FDR Drive', '1'),
#  ('W 15 St & 7 Ave', '1'),
#  ('W 29 St & 9 Ave', '1'),
#  ...]
